# %% [markdown]
# <a href="https://colab.research.google.com/github/Erijames/Analise-covid19/blob/main/Analise_do_Covid19.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd


confirmed_df = pd.read_csv('https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_confirmed_global.csv')
deaths_df = pd.read_csv('https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_deaths_global.csv')
recoveries_df = pd.read_csv('https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_recovered_global.csv')

'''
print(confirmed_df)
print(deaths_df)
print(recoveries_df)
'''

date = '3/14/21' # Data no padrão m/d/aa

df_confirmed = pd.DataFrame(confirmed_df[["Country/Region",date]].groupby("Country/Region").sum())
df_confirmed = df_confirmed.sort_values(by=date,ascending=False)
df_confirmed.columns = ['Confirmados']
table1 = df_confirmed.head(50)

df_deaths = pd.DataFrame(deaths_df[["Country/Region",date]].groupby("Country/Region").sum())
df_deaths = df_deaths.sort_values(by=date,ascending=False)
df_deaths.columns = ['Mortes']
table2 = df_deaths.head(50)


df_recoveries = pd.DataFrame(recoveries_df[["Country/Region",date]].groupby("Country/Region").sum())
df_recoveries = df_recoveries.sort_values(by=date,ascending=False)
df_recoveries.columns = ['Recuperados']
table3 = df_recoveries.head(50)


tl = ((df_deaths['Mortes'] / df_confirmed['Confirmados'])*100).to_frame()
tl = tl.rename(columns={0: 'Taxa Let'})
table4 = tl.head(50)
print(table4)

result = pd.concat([df_confirmed, df_deaths, df_recoveries], axis=1, join="inner").join(tl)
table5 = result.head(50)
print(table5)
#print(table5.describe())

table5 = str(table5)
with open('covid-19.doc','wb') as f:
    f.write(table5.encode())
f.close()
# Out:
#                           Taxa Let
# Country/Region
# Afghanistan               4.388676
# Albania                   1.740811
# Algeria                   2.633931
# Andorra                   1.003018
# Angola                    2.436857
# Antigua and Barbuda       2.803738
# Argentina                 2.444299
# Armenia                   1.824705
# Australia                 3.120494
# Austria                   1.797726
# Azerbaijan                1.365821
# Bahamas                   2.136752
# Bahrain                   0.369463
# Bangladesh                1.533024
# Barbados                  1.081555
# Belarus                   0.692967
# Belgium                   2.776379
# Belize                    2.554568
# Benin                     1.245962
# Bhutan                    0.115207
# Bolivia                   4.610064
# Bosnia and Herzegovina    3.830895
# Botswana                  1.243475
# Brazil                    2.422886
# Brunei                    1.507538
# Bulgaria                  4.051235
# Burkina Faso              1.163919
# Burma                     2.252598
# Burundi                   0.121902
# Cabo Verde                0.968884
# Cambodia                  0.075472
# Cameroon                  1.479494
# Canada                    2.455185
# Central African Republic  1.254231
# Chad                      3.573915
# Chile                     2.432247
# China                     4.773225
# Colombia                  2.654762
# Comoros                   4.016506
# Congo (Brazzaville)       1.404223
# Congo (Kinshasa)          2.654179
# Costa Rica                1.368769
